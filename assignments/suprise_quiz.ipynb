# %%
import pandas as pd

# %% [markdown]
# # 1
# A
# # 2
# A
# # 3
# B
# # 4
# B
# # 5
# B
# # 6
# B
# # 7
# B
# # 8
# B
# # 9
# C
# # 10
# B
# # 11
# B
# # 12
# B
# # 13
# B
# # 14
# B
# # 15
# B

# %% [markdown]
# # 16
# C
# # 17
# B
# # 18
# B
# # 19
# A
# # 20
# B
# # 21
# B
# # 22
# A
# # 23
# C
# # 24
# B
# # 25
# B
# # 26
# B
# # 27
# A
# # 28
# B
# # 29
# A
# # 30
# B
# # 31
# C
# # 32
# B
# # 33
# A
# # 34
# B
# # 35
# B
# # 36
# B
# # 37
# A
# # 38
# A
# # 39
# B
# # 40
# B

# %% [markdown]
# # 41
# B
#
# # 42
# C
#
# # 43
# B
#
# # 44
# B
#
# # 45
# C
#
# # 46
# A
#
# # 47
# B
#
# # 48
# B
#
# # 49
# C
#
# # 50
# B
#
# # 51
# B
#
# # 52
# B
#
# # 53
# B
#
# # 54
# C
#
# # 55
# B
#
# # 56
# B
#
# # 57
# A
#
# # 58
# B
#
# # 59
# B
#
# # 60
# B

# %% [markdown]
# # 61
# B
#
# # 62
# B
#
# # 63
# A
#
# # 64
# B
#
# # 65
# A
#
# # 66
# B
#
# # 67
# B
#
# # 68
# B
#
# # 69
# A
#
# # 70
# B
#
# # 71
# B
#
# # 72
# B
#
# # 73
# B
#
# # 74
# B
#
# # 75
# B
#
# # 76
# B
#
# # 77
# B
#
# # 78
# B
#
# # 79
# B
#
# # 80
# C
#
# # 81
# B
#
# # 82
# A
#
# # 83
# B
#
# # 84
# B
#
# # 85
# B
#
# # 86
# A
#
# # 87
# B
#
# # 88
# B
#
# # 89
# A
#
# # 90
# A
#
# # 91
# B
#
# # 92
# B
#
# # 93
# B
#
# # 94
# B
#
# # 95
# B
#
# # 96
# B
#
# # 97
# B
#
# # 98
# B
#
# # 99
# B
#
# # 100
# B
# # 90

# %%
import pandas as pd
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
print(df["A"].sum())
# Out:
# 6

# %%
import numpy as np
arr = np.array([1, 2, 3, 4])
print(arr.shape)
# Out:
# (4,)

# %%
class Animal:
    def speak(self):
        return "Sound"
class Dog(Animal):
    def speak(self):
        return "Bark"
a = Dog()
print(a.speak())
# Out:
# Bark

# %%
print(max([4, 9, 2, 7]))
# Out:
# 9

# %%
x = list([4, 5])
type(x)
# Out:
# list

# %%
lst = [1, 2, 3]
lst.append([4, 5])
print(lst)
# Out:
# [1, 2, 3, [4, 5]]

# %%
lst = [1, 2, 3]
lst.append([4, 5])
print(lst)
# Out:
# [1, 2, 3, [4, 5]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       2 lst.append([4, 5])
#       3 print(lst)
# ----> 4 iterabe(lst)
#
# NameError: name 'iterabe' is not defined

# %%
iter(lst)

# %%
iter(extend())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 iter(extend())
#
# NameError: name 'extend' is not defined
