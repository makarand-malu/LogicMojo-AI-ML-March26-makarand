# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# 1. HANDLE EXCEPTIONS
# Safely process each record
# Skip bad records but log errors
#
# 2. USE ASSERT
# Ensure:
# User name is not NULL
# Amount > 0
#
# 3. REGEX EXTRACTION
# Extract:
# name
# phone (valid 10 digits only)
# email (valid format)
# amount (only numbers)
#
# 4. ADVANCED REGEX
# Extract currency:
# Rs
# USD
#
# 5. STRING CLEANING
# lowercase everything
# remove special characters
#
#
# 6. FINAL OUTPUT
# Return clean structured dataset:
# [
#  {'name': 'mahipal', 'phone': '9876543210', 'email': 'mahi@gmail.com', 'amount': 5000, 'currency': 'rs'},
#  ...
# ]

# %%
data = [
    "User: Mahipal | Phone: 9876543210 | Email: mahi@gmail.com | Amount: Rs.5000",
    "User: Ravi | Phone: 98765abc10 | Email: ravi#gmail.com | Amount: USD300",
    "User: NULL | Phone: 9123456789 | Email: test@yahoo.com | Amount: Rs.7000",
    "User: Ankit | Phone: 9999999999 | Email: ankit@gmail.com | Amount: Rs.0",
    "User: Sita | Phone: 8888888888 | Email: sita@gmail.com | Amount: Rs.-100"]

# %%
valid_records = []
errors = []
for i, item in enumerate(data):
    try:
        parts = item.split(' | ')
        name = parts[0].split(': ')[1]
        phone = parts[1].split(': ')[1]
        email = parts[2].split(': ')[1]
        amount = parts[3].split(': ')[1]
        amount_digits = re.search('-?\d+', amount)
        amount = int(amount_digits.group())
       
        
        # print(name, phone, email, amount)
        # assert: 
        # Optional validations
        if not phone.isdigit():
            raise ValueError("Invalid phone number")
            
         # --- Assertions (business rules) ---
        assert name != "NULL", "User name is NULL"
        assert amount > 0, "Amount must be greater than 0"

        if not phone.isdigit():
            raise ValueError("Invalid phone number")

        if "@" not in email:
            raise ValueError("Invalid email format")

         # If all checks pass
        valid_records.append({
            "name": name,
            "phone": phone,
            "email": email,
            "amount": amount
        })
    
    except AssertionError as ae:
        errors.append(f"Record {i+1}: AssertionError - {str(ae)}")
        
    except Exception as e:
        errors.append(f"Record {i+1}: Error - {str(e)}")

print("Valid Records")
print(valid_records)

print(f"\nERRORS ")
for e in errors:
    print(e)
# Out:
# Valid Records
# [{'name': 'Mahipal', 'phone': '9876543210', 'email': 'mahi@gmail.com', 'amount': 5000}]
#
# ERRORS
# Record 2: Error - Invalid phone number
# Record 3: AssertionError - User name is NULL
# Record 4: AssertionError - Amount must be greater than 0
# Record 5: AssertionError - Amount must be greater than 0
